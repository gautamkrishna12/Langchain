# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ['NEO4J_URI']=os.getenv('NEO4J_URI')
os.environ['NEO4J_USERNAME']=os.getenv('NEO4J_USERNAME')
os.environ['NEO4J_PASSWORD']=os.getenv('NEO4J_PASSWORD')

# %%
from langchain_community.graphs import Neo4jGraph
Graph=Neo4jGraph(url=os.getenv('NEO4J_URI'),username=os.getenv('NEO4J_USERNAME'),password=os.getenv('NEO_API_KEY'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 from langchain_community.graphs import Neo4jGraph
# ----> 2 Graph=Neo4jGraph(url=os.getenv('NEO4J_URI'),username=os.getenv('NEO4J_USERNAME'),password=os.getenv('NEO_API_KEY'))
#
# File ~/My Folder /Learn/Langchain/langgraph_venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:221, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     219     warned = True
#     220     emit_warning()
# --> 221 return wrapped(self, *args, **kwargs)
#
# File ~/My Folder /Learn/Langchain/langgraph_venv/lib/python3.11/site-packages/langchain_community/graphs/neo4j_graph.py:429, in Neo4jGraph.__init__(self, url, username, password, database, timeout, sanitize, refresh_schema, driver_config, enhanced_schema)
#     427 if refresh_schema:
#     428     try:
# --> 429         self.refresh_schema()
#     430     except neo4j.exceptions.ClientError as e:
#     431         if e.code == "Neo.ClientError.Procedure.ProcedureNotFound":
#
# File ~/My Folder /Learn/Langchain/langgraph_venv/lib/python3.11/site-packages/langchain_community/graphs/neo4j_graph.py:511, in Neo4jGraph.refresh_schema(self)
#     504 """
#     505 Refreshes the Neo4j graph schema information.
#     506 """
#     507 from neo4j.exceptions import ClientError, CypherTypeError
#     509 node_properties = [
#     510     el["output"]
# --> 511     for el in self.query(
#     512         node_properties_query,
#     513         params={"EXCLUDED_LABELS": EXCLUDED_LABELS + [BASE_ENTITY_LABEL]},
#     514     )
#     515 ]
#     516 rel_properties = [
#     517     el["output"]
#     518     for el in self.query(
#     519         rel_properties_query, params={"EXCLUDED_LABELS": EXCLUDED_RELS}
#     520     )
#     521 ]
#     522 relationships = [
#     523     el["output"]
#     524     for el in self.query(
#    (...)    527     )
#     528 ]
#
# File ~/My Folder /Learn/Langchain/langgraph_venv/lib/python3.11/site-packages/langchain_community/graphs/neo4j_graph.py:467, in Neo4jGraph.query(self, query, params)
#     464 from neo4j.exceptions import Neo4jError
#     466 try:
# --> 467     data, _, _ = self._driver.execute_query(
#     468         Query(text=query, timeout=self.timeout),
#     469         database_=self._database,
#     470         parameters_=params,
#     471     )
#     472     json_data = [r.data() for r in data]
#     473     if self.sanitize:
#
# File ~/My Folder /Learn/Langchain/langgraph_venv/lib/python3.11/site-packages/neo4j/_sync/driver.py:869, in Driver.execute_query(self, query_, parameters_, routing_, database_, impersonated_user_, bookmark_manager_, auth_, result_transformer_, **kwargs)
#     866     raise ValueError("Invalid routing control value: %r"
#     867                      % routing_)
#     868 with session._pipelined_begin:
# --> 869     return session._run_transaction(
#     870         access_mode, TelemetryAPI.DRIVER,
#     871         _work, (query_, parameters, result_transformer_), {}
#     872     )
#
# File ~/My Folder /Learn/Langchain/langgraph_venv/lib/python3.11/site-packages/neo4j/_sync/work/session.py:548, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     546 tx = self._transaction
#     547 try:
# --> 548     result = transaction_function(tx, *args, **kwargs)
#     549 except asyncio.CancelledError:
#     550     # if cancellation callback has not been called yet:
#     551     if self._transaction is not None:
#
# File ~/My Folder /Learn/Langchain/langgraph_venv/lib/python3.11/site-packages/neo4j/_sync/driver.py:1194, in _work(tx, query, parameters, transformer)
#    1188 def _work(
#    1189     tx: ManagedTransaction,
#    1190     query: str,
#    1191     parameters: t.Dict[str, t.Any],
#    1192     transformer: t.Callable[[Result], t.Union[_T]]
#    1193 ) -> _T:
# -> 1194     res = tx.run(query, parameters)
#    1195     if transformer is Result.to_eager_result:
#    1196         return transformer(res)
#
# File ~/My Folder /Learn/Langchain/langgraph_venv/lib/python3.11/site-packages/neo4j/_sync/work/transaction.py:144, in TransactionBase.run(self, query, parameters, **kwparameters)
#     113 """ Run a Cypher query within the context of this transaction.
#     114
#     115 Cypher is typically expressed as a query template plus a
#    (...)    141 :returns: a new :class:`neo4j.Result` object
#     142 """
#     143 if isinstance(query, Query):
# --> 144     raise ValueError("Query object is only supported for session.run")
#     146 if self._closed_flag:
#     147     raise TransactionError(self, "Transaction closed")
#
# ValueError: Query object is only supported for session.run

# %%
os.getenv('NEO4J_PASSWORD')
# Out:
# 'jQzVE3g19i8PKITQZqdmrw7eTw0rtCX7Nurw9f-3Ymc'

# %%
os.getenv('NEO4J_USERNAME')
# Out:
# 'neo4j'

# %%
os.getenv('NEO4J_URI')
# Out:
# 'neo4j+s://88bb3034.databases.neo4j.io'

# %%
import neo4j
print(neo4j.__version__)
# Out:
# 5.14.0
